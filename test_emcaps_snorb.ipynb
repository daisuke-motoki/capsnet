# %%
from io_utils import binary_matrix
import matplotlib.pyplot as plt

# %%
train_data = binary_matrix.load("/Users/daisuke.motoki/data/smallNORB/smallnorb-5x46789x9x18x6x2x96x96-training-dat.mat")
train_cat = binary_matrix.load("/Users/daisuke.motoki/data/smallNORB/smallnorb-5x46789x9x18x6x2x96x96-training-cat.mat")
train_info = binary_matrix.load("/Users/daisuke.motoki/data/smallNORB/smallnorb-5x46789x9x18x6x2x96x96-training-info.mat")

# %%
train_info[0]
# Out:
# array([8, 6, 4, 4], dtype=int32)

# %%
index =2
figs = plt.figure(figsize=(7,14))
sub = figs.add_subplot(1,2,1)
sub.imshow(train_data[index][0], cmap="gray")
sub= figs.add_subplot(1,2,2)
sub.imshow(train_data[index][1], cmap="gray")
plt.show()
